# %% [markdown]
# ## What is Pandas ?
#
# Pandas is a software library written for the python programming language
# for data **manipulation and analysis.**
#
# * Pandas is built on top of the NumPy package, meaning a lot of the structure of NumPy is used or replicated in Pandas.
# * Data in pandas is often used to feed statistical analysis in SciPy, plotting functions from Matplotlib, and machine learning algorithms in Scikit-learn.
# * The primary two components of pandas are the **Series and DataFrame**

# %% [markdown]
# ## Loan dataset
#
# https://www.kaggle.com/animeshparikshya/loan-dataset

# %% [markdown]
# ## Importing  required libraries

# %%
import numpy as np
print('numpy version : ', np.__version__)

import pandas as pd
print('pandas version : ', pd.__version__)

import warnings
warnings.filterwarnings('ignore')
# Out:
# numpy version :  1.19.5
# pandas version :  1.1.5

# %% [markdown]
# ## 1.Read CSV using pandas.read_csv()
#
# * 1.1 **pd.read_csv():** used to read data from CSV file.
# * 1.2 **header = [1, 2]:** param used to treat given rows number as header.
# * 1.3 **index_col = 'column_name':** param used to treat given column as header.
# * 1.4 **usecols = ['column_name']:** param used to get only specified column name from CSV.
# * 1.5 **skiprows = [1, 2]:** param used to skip given rows from CSV while reading data from CSV.

# %% [markdown]
# ### Read data from CSV

# %%
data = pd.read_csv("dataset/loan.csv")
data
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 0               1.0         Urban           Y
# 1               1.0         Rural           N
# 2               1.0         Urban           Y
# 3               1.0         Urban           Y
# 4               1.0         Urban           Y
# ..              ...           ...         ...
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# 611             1.0         Urban           Y
# 612             1.0         Urban           Y
# 613             0.0     Semiurban           N
#
# [614 rows x 13 columns]

# %% [markdown]
# ### Make the first two rows as header.

# %%
data = pd.read_csv("dataset/loan.csv", header =[1, 2])
data
# Out:
#      LP001002    Male   No   0      Graduate   No  5849       0  \
#      LP001003    Male  Yes   1      Graduate   No  4583    1508
# 0    LP001005    Male  Yes   0      Graduate  Yes  3000     0.0
# 1    LP001006    Male  Yes   0  Not Graduate   No  2583  2358.0
# 2    LP001008    Male   No   0      Graduate   No  6000     0.0
# 3    LP001011    Male  Yes   2      Graduate  Yes  5417  4196.0
# 4    LP001013    Male  Yes   0  Not Graduate   No  2333  1516.0
# ..        ...     ...  ...  ..           ...  ...   ...     ...
# 607  LP002978  Female   No   0      Graduate   No  2900     0.0
# 608  LP002979    Male  Yes  3+      Graduate   No  4106     0.0
# 609  LP002983    Male  Yes   1      Graduate   No  8072   240.0
# 610  LP002984    Male  Yes   2      Graduate   No  7583     0.0
# 611  LP002990  Female   No   0      Graduate  Yes  4583     0.0
#
#     Unnamed: 8_level_0    360    1      Urban  Y
#                    128    360    1      Rural  N
# 0                 66.0  360.0  1.0      Urban  Y
# 1                120.0  360.0  1.0      Urban  Y
# 2                141.0  360.0  1.0      Urban  Y
# 3                267.0  360.0  1.0      Urban  Y
# 4                 95.0  360.0  1.0      Urban  Y
# ..                 ...    ...  ...        ... ..
# 607               71.0  360.0  1.0      Rural  Y
# 608               40.0  180.0  1.0      Rural  Y
# 609              253.0  360.0  1.0      Urban  Y
# 610              187.0  360.0  1.0      Urban  Y
# 611              133.0  360.0  0.0  Semiurban  N
#
# [612 rows x 13 columns]

# %% [markdown]
# ### Make column as Index column.

# %%
data = pd.read_csv("dataset/loan.csv", index_col = 'Loan_ID')
data
# Out:
#           Gender Married Dependents     Education Self_Employed  \
# Loan_ID
# LP001002    Male      No          0      Graduate            No
# LP001003    Male     Yes          1      Graduate            No
# LP001005    Male     Yes          0      Graduate           Yes
# LP001006    Male     Yes          0  Not Graduate            No
# LP001008    Male      No          0      Graduate            No
# ...          ...     ...        ...           ...           ...
# LP002978  Female      No          0      Graduate            No
# LP002979    Male     Yes         3+      Graduate            No
# LP002983    Male     Yes          1      Graduate            No
# LP002984    Male     Yes          2      Graduate            No
# LP002990  Female      No          0      Graduate           Yes
#
#           ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Loan_ID
# LP001002             5849                0.0         NaN             360.0
# LP001003             4583             1508.0       128.0             360.0
# LP001005             3000                0.0        66.0             360.0
# LP001006             2583             2358.0       120.0             360.0
# LP001008             6000                0.0       141.0             360.0
# ...                   ...                ...         ...               ...
# LP002978             2900                0.0        71.0             360.0
# LP002979             4106                0.0        40.0             180.0
# LP002983             8072              240.0       253.0             360.0
# LP002984             7583                0.0       187.0             360.0
# LP002990             4583                0.0       133.0             360.0
#
#           Credit_History Property_Area Loan_Status
# Loan_ID
# LP001002             1.0         Urban           Y
# LP001003             1.0         Rural           N
# LP001005             1.0         Urban           Y
# LP001006             1.0         Urban           Y
# LP001008             1.0         Urban           Y
# ...                  ...           ...         ...
# LP002978             1.0         Rural           Y
# LP002979             1.0         Rural           Y
# LP002983             1.0         Urban           Y
# LP002984             1.0         Urban           Y
# LP002990             0.0     Semiurban           N
#
# [614 rows x 12 columns]

# %% [markdown]
# ### Use only selected columns from CSV file.

# %%
data = pd.read_csv("dataset/loan.csv", usecols =["Education"])
data
# Out:
#         Education
# 0        Graduate
# 1        Graduate
# 2        Graduate
# 3    Not Graduate
# 4        Graduate
# ..            ...
# 609      Graduate
# 610      Graduate
# 611      Graduate
# 612      Graduate
# 613      Graduate
#
# [614 rows x 1 columns]

# %%
data = pd.read_csv("dataset/loan.csv", usecols =["Gender", "Education"])
data
# Out:
#      Gender     Education
# 0      Male      Graduate
# 1      Male      Graduate
# 2      Male      Graduate
# 3      Male  Not Graduate
# 4      Male      Graduate
# ..      ...           ...
# 609  Female      Graduate
# 610    Male      Graduate
# 611    Male      Graduate
# 612    Male      Graduate
# 613  Female      Graduate
#
# [614 rows x 2 columns]

# %% [markdown]
# ### Skip rows whlile reading data from CSV file.

# %%
data = pd.read_csv("dataset/loan.csv", skiprows = [1, 2, 3, 4])
data
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001008    Male      No          0      Graduate            No
# 1    LP001011    Male     Yes          2      Graduate           Yes
# 2    LP001013    Male     Yes          0  Not Graduate            No
# 3    LP001014    Male     Yes         3+      Graduate            No
# 4    LP001018    Male     Yes          2      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 605  LP002978  Female      No          0      Graduate            No
# 606  LP002979    Male     Yes         3+      Graduate            No
# 607  LP002983    Male     Yes          1      Graduate            No
# 608  LP002984    Male     Yes          2      Graduate            No
# 609  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               6000                0.0       141.0             360.0
# 1               5417             4196.0       267.0             360.0
# 2               2333             1516.0        95.0             360.0
# 3               3036             2504.0       158.0             360.0
# 4               4006             1526.0       168.0             360.0
# ..               ...                ...         ...               ...
# 605             2900                0.0        71.0             360.0
# 606             4106                0.0        40.0             180.0
# 607             8072              240.0       253.0             360.0
# 608             7583                0.0       187.0             360.0
# 609             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 0               1.0         Urban           Y
# 1               1.0         Urban           Y
# 2               1.0         Urban           Y
# 3               0.0     Semiurban           N
# 4               1.0         Urban           Y
# ..              ...           ...         ...
# 605             1.0         Rural           Y
# 606             1.0         Rural           Y
# 607             1.0         Urban           Y
# 608             1.0         Urban           Y
# 609             0.0     Semiurban           N
#
# [610 rows x 13 columns]

# %% [markdown]
# ## 2.Saving a Pandas dataframe as a CSV
#
# * 2.1 **pd.to_csv():** used to write dataframe data into CSV file.
# * 2.2 **header = False:** param used to remove header from CSV file.
# * 2.3 **index = False:** param used to remove index from CSV file.

# %% [markdown]
# ### Create a dataframe.

# %%
data = {'Name':['Name_1', 'Name_2', 'Name_3', 'Name_4'], 
             'Age':[27, 24, 22, 32], 
             'Address':['Nagpur', 'Delhi', 'Bangalore', 'Meerut'], 
             'Qualification':['MSC', 'M.A', 'MCA', 'PHD']} 
   
df = pd.DataFrame(data)
df
# Out:
#      Name  Age    Address Qualification
# 0  Name_1   27     Nagpur           MSC
# 1  Name_2   24      Delhi           M.A
# 2  Name_3   22  Bangalore           MCA
# 3  Name_4   32     Meerut           PHD

# %% [markdown]
# ### Save dataframe data into CSV file

# %%
df.to_csv('dataset/csv_file.csv')

# %%
data = pd.read_csv("dataset/csv_file.csv")
data
# Out:
#    Unnamed: 0    Name  Age    Address Qualification
# 0           0  Name_1   27     Nagpur           MSC
# 1           1  Name_2   24      Delhi           M.A
# 2           2  Name_3   22  Bangalore           MCA
# 3           3  Name_4   32     Meerut           PHD

# %% [markdown]
# ### Save dataframe data into CSV file without header and index

# %%
df.to_csv('dataset/csv_file.csv', header=False, index=False)

# %%
data = pd.read_csv("dataset/csv_file.csv")
data
# Out:
#    Name_1  27     Nagpur  MSC
# 0  Name_2  24      Delhi  M.A
# 1  Name_3  22  Bangalore  MCA
# 2  Name_4  32     Meerut  PHD

# %% [markdown]
# ## Quick Recap

# %% [markdown]
# ### 1.Read CSV using pandas.read_csv()
#
# * 1.1 **pd.read_csv():** used to read data from CSV file.
# * 1.2 **header = [1, 2]:** param used to treat given rows number as header.
# * 1.3 **index_col = 'column_name':** param used to treat given column as header.
# * 1.4 **usecols = ['column_name']:** param used to get only specified column name from CSV.
# * 1.5 **skiprows = [1, 2]:** param used to skip given rows from CSV while reading data from CSV.
#
#
# ### 2.Saving a Pandas dataframe as a CSV
#
# * 2.1 **pd.to_csv():** used to write dataframe data into CSV file.
# * 2.2 **header = False:** param used to remove header from CSV file.
# * 2.3 **index = False:** param used to remove index from CSV file.
